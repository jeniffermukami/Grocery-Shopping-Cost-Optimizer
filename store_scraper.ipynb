# %%
from bs4 import BeautifulSoup as soup
from IPython.display import display_html
from lxml import etree
import numpy as np
import pandas as pd
import requests
import warnings
import time
import re
warnings.filterwarnings('ignore')

# %%
SHOPRITE_SEARCH_URL = 'https://www.shoprite.co.za/search/all?q='
SHOPRITE_URL = 'https://www.shoprite.co.za'

CHECKERS_SEARCH_URL = 'https://www.checkers.co.za/search/all?q='
CHECKERS_URL = 'https://www.checkers.co.za/'

WOOLWORTHS_SEARCH_URL = 'https://www.woolworths.co.za/cat/Food/Pantry/_/N-1lw4dzx'
WOOLWORTHS_URL = 'https://www.woolworths.co.za/'

# %%
FOOD_BASKET = ['large eggs 6', 'large eggs 18', 'extra large eggs 30', 'table salt 500g',
               'table salt 1kg', 'rice 2kg', 'rice 5kg', 'rice 1kg', 'rice canister 10l', 
              'sugar 500g', 'sugar 1kg', 'sugar 2.5kg', 'sugar 5kg', 'sugar 10kg',
              'flour 500g', 'flour 1kg', 'flour 2.5kg', 'flour 5kg', 'flour 10kg',
              'frozen chicken', 'pork bangers', 'pork rashers', 'pork loin chops',
              'pork braai chops', 'pork chops', 'pork shoulder ribs', 'stewing pork',
              'beef goulash', 'ground beef', 'beef parcel', 'beef brisket', 'coarse salt 500g',
              'fine salt 500g', 'medium salt 500g']

# %%
user_basket = np.random.choice(FOOD_BASKET, 1)

# %%
def fetch_html(url):
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
    response = requests.get(url, verify=False, headers=headers, timeout=10)
    print("html downloaded successfully")
    page = soup(response.content, 'html.parser')

    return page

# %%
def extract_product_links(html_page):
  
    product_div = html_page.find('div', {"class": re.compile('(\w+-)*search-landing')})
    content = product_div.find('div', class_='yCmsContentSlot')
    component = content.find('div', class_='yCmsComponent')
    product_wrappers = component.find('div', class_='search-landing__block--products')
    product_row = product_wrappers.find('div', class_='row')
    products = product_row.findAll('div', class_='product-frame')
    
    links = []
    for product in products:
        figure = product.find('figure')
        product_link = figure.find('a', href=True)['href']
        links.append(product_link)
    
    return links

# %%
def match_product_url(links_arr, item):
    
    pattern = r'([\w+-/%?]+' + str(item.replace(' ', '\-')) + '[\w+-/%?]+)'

    found = []

    for link in links_arr:
        try:
            match = re.search(pattern, link.lower()).group()
            found.append({link: match})
        except Exception:
            None
    
    return found

# %%
def extract_brand(link):
    
    text = list(link.values())[0].split('/')[-3]
    
    try:
        value = re.search(r'(\d+(\-)?\d+)', text).group()
        new_link = re.sub(value, value.replace('-', '.'), text)
        
    except Exception:
        new_link = text
    
    
    return new_link.replace('-', ' ').title()

# %%
def get_brands(arr_links):
    
    brands = []
    counter = 1
    
    for item in arr_links:
        brands.append({counter: extract_brand(item)})
        counter+=1
        
    return brands

# %%
def evaluate_user_choice(user_choice, links, matching_product_urls, brands, item, store_url):
    
    html = ""
    for brand in brands:
        for key, value in brand.items():
            if eval(user_choice) == key:
                k_found = match_product_url(list(matching_product_urls[0].keys()), item)
                if len(k_found) == 0:
                    k_found = closest_products(links, matching_product_urls)
                url = list(k_found[0].keys())[0]
                k_fetch = fetch_html(store_url+url)
                html = k_fetch
                
    return html

# %%
def get_product_details(html):
    product_specs = {}
    
    product_div = html.find('div', class_='pdp')
    product_details = product_div.find('div', class_='pdp__details')
    regex = r'\d+\.\d+'
    price = re.search(regex, product_details.find('div', class_='special-price__price').find('span').get_text().strip().lstrip('R')).group()

    try:
        promo_price = product_details.find('div', class_='special-price__extra').find('span').get_text().strip().lstrip('R')
        promo_condition = product_details.find('span', class_='special-price__extra__text').get_text()
    except Exception:
        promo_price = None
        promo_condition = None
        
    try:
        extra_details = product_div.find('div', 'pdp__extras')
        offer = extra_details.find('div', class_= 'extra-message').find('span', class_='extra-message__title').get_text().strip()
        promo_price_1 = re.search(regex, offer).group()
        promo_duration = extra_details.find('div', class_= 'extra-message').find('span', class_='extra-message__valid').get_text().strip().replace('&nbsp;' '')
    except Exception:
        offer = None
        promo_price_1 = None
        promo_duration = None
    
    if not promo_price and not promo_price_1:
        promo_price = None
        
    elif not promo_price and promo_price_1:
        promo_price = promo_price_1
    
    else:
        promo_price = promo_price
        
    product_desc = product_details.find('div', class_='pdp__description').get_text()
    product_name = product_details.find('h1', class_='pdp__name').get_text()
    product_brand = product_name.split()[0]
    product_image_url = SHOPRITE_URL + product_div.find('div', class_='pdp__image').find('img')['src']

    product_specs['Brand'] = product_brand
    product_specs['Name'] = product_name + "**" if promo_price and (price > promo_price) else product_name
    product_specs['Description'] = product_desc
    product_specs['Regular Price'] = price
    product_specs['Offer'] = offer
    product_specs['Promo Price'] = promo_price
    product_specs['Promo Condition'] = promo_condition
    product_specs['Product Image'] = product_image_url
    
    return product_specs

# %%
def total_cost(basket_details):
    
    receipt = {}
    total_cost = 0
    regular_total = 0

    for item in basket_details:
        if item['Promo Price'] and (item['Promo Price'] < item['Regular Price']):
            price = item['Promo Price']
        else:
            price = item['Regular Price']

        total_cost += float(price)
        regular_total += float(item['Regular Price'])
        
        receipt[item['Name']] =  (price, item['Regular Price'])
    
    receipt['Total'] = ("R " + str(round(total_cost,2)), "R " + str(round(regular_total, 2)))
    receipt['Savings'] = (f"R {round(abs(total_cost - regular_total), 2)}", "-")
    
    return receipt

# %%
def closest_products(product_links, product_match):
    all_matches = []
    key = product_links
    value = [link.lower() for link in product_links]
    
    for i in range(len(key)):
        all_matches.append(dict(zip([key[i]], [value[i]])))
    product_match = all_matches
    
    return product_match

# %%
def evaluate_user_basket(basket, search_url, store_url):
    user_product_details = []

    for item in basket:
        search_result = fetch_html(search_url+item)
        product_links = extract_product_links(search_result)
        product_match = match_product_url(product_links, item)
        if len(product_match) == 0:
            product_match = closest_products(product_links, product_match)
        product_brands = get_brands(product_match)

        print(product_brands)

        user_choice = input('select brand > ')
        html = evaluate_user_choice(user_choice, product_links, product_match, product_brands, item, store_url)
        product_details = get_product_details(html)

        user_product_details.append(product_details)

        basket_cost = total_cost(user_product_details)
        
    return basket_cost

# %%
def get_receipt(receipt):
    receipt = pd.DataFrame.from_dict(receipt, orient='index',
                                    columns=['Price', 'Regular Price'])

    return receipt

# %%
def compare_stores(stores, user_basket):
    receipts = []
    promos = {}
    for store in stores:
        for name, urls in store.items():
            store_receipt = evaluate_user_basket(basket=user_basket, search_url=urls[0], store_url=urls[1])
            receipt = get_receipt(store_receipt)
            promo_total = receipt.iloc[-2].values[0].strip('R').strip()
            promos[name] = promo_total
            receipt_styler = receipt.style\
                        .set_table_attributes("style='display:inline; margin-right:30px'")\
                        .set_caption(name.upper() + ' RECEIPT')
            
            receipts.append(receipt_styler)
    print("#"*120)
    display_html([tbl._repr_html_() for tbl in receipts], raw=True)
    
    min_total = min(promos.values())
    for store, total in promos.items():
        if total == min_total:
            return (f" WE RECOMMEND SHOPPING FROM {store} ".upper().center(100, "*"))

# %%
stores = [{"checkers": (CHECKERS_SEARCH_URL, CHECKERS_URL)}]

# %%
compare_stores(stores, user_basket)
# Out:
# html downloaded successfully
# [{1: 'Buffalo Fine Sea Salt 500G'}, {2: 'Buffalo Fine Sea Salt 1Kg'}, {3: 'Imbo Fine Desiccated Coconut 500G'}, {4: 'Medirite Epsom Salts 500G'}, {5: 'Cerebos Iodated Table Salt 1Kg'}, {6: 'Cerebos Iodated Table Salt 500G'}, {7: 'Cerebos Iodated Table Salt Pack 1Kg'}, {8: 'Bonnita Salted Butter Brick 500G'}, {9: 'Kim Isodated Coarse Salt 500G'}, {10: 'Marina Lighthouse Salt Flask 500G'}]
# select brand >  2
# html downloaded successfully
# html downloaded successfully
# [{1: 'Lunds Large Eggs 6 Pack'}, {2: 'Lunds Extra Large Eggs 6 Pack'}, {3: 'Nulaid Premium Grade 1 Canola Large Eggs 6 X %3E51G'}, {4: 'Nulaid Premium Grade 1 Canola Extra Large Eggs 6 X %3E59G'}]
# select brand >  3
# html downloaded successfully
# html downloaded successfully
# [{1: 'Huletts White Sugar 2.5Kg'}, {2: 'Checkers Housebrand White Sugar 2.5Kg'}, {3: 'Huletts Kosher White Sugar 2.5Kg Bag'}]
# select brand >  1
# html downloaded successfully
# html downloaded successfully
# [{1: 'Cerebos Iodated Table Salt 500G'}, {2: 'Cerebos Iodated Table Salt 500G'}, {3: 'Checkers Housebrand Iodated Table Salt 500G'}]
# select brand >  1
# html downloaded successfully
# html downloaded successfully
# [{1: 'Huletts White Sugar 5Kg'}, {2: 'Selati White Sugar 5Kg'}, {3: 'Selati Golden Brown Sugar 5Kg'}]
# select brand >  3
# html downloaded successfully
# <style type="text/css">
# </style>
# <table id="T_ad846" style='display:inline; margin-right:30px'>
#   <caption>CHECKERS RECEIPT</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad846_level0_col0" class="col_heading level0 col0" >Price</th>
#       <th id="T_ad846_level0_col1" class="col_heading level0 col1" >Regular Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad846_level0_row0" class="row_heading level0 row0" >Buffalo Fine Sea Salt 500g</th>
#       <td id="T_ad846_row0_col0" class="data row0 col0" >8.99</td>
#       <td id="T_ad846_row0_col1" class="data row0 col1" >8.99</td>
#     </tr>
#     <tr>
#       <th id="T_ad846_level0_row1" class="row_heading level0 row1" >Lunds Large Eggs 6 Pack</th>
#       <td id="T_ad846_row1_col0" class="data row1 col0" >15.99</td>
#       <td id="T_ad846_row1_col1" class="data row1 col1" >15.99</td>
#     </tr>
#     <tr>
#       <th id="T_ad846_level0_row2" class="row_heading level0 row2" >Huletts White Sugar 2.5kg</th>
#       <td id="T_ad846_row2_col0" class="data row2 col0" >49.99</td>
#       <td id="T_ad846_row2_col1" class="data row2 col1" >49.99</td>
#     </tr>
#     <tr>
#       <th id="T_ad846_level0_row3" class="row_heading level0 row3" >Cerebos Iodated Table Salt 500g</th>
#       <td id="T_ad846_row3_col0" class="data row3 col0" >24.99</td>
#       <td id="T_ad846_row3_col1" class="data row3 col1" >24.99</td>
#     </tr>
#     <tr>
#       <th id="T_ad846_level0_row4" class="row_heading level0 row4" >Huletts White Sugar 5kg</th>
#       <td id="T_ad846_row4_col0" class="data row4 col0" >102.99</td>
#       <td id="T_ad846_row4_col1" class="data row4 col1" >102.99</td>
#     </tr>
#     <tr>
#       <th id="T_ad846_level0_row5" class="row_heading level0 row5" >Total</th>
#       <td id="T_ad846_row5_col0" class="data row5 col0" >R 202.95</td>
#       <td id="T_ad846_row5_col1" class="data row5 col1" >R 202.95</td>
#     </tr>
#     <tr>
#       <th id="T_ad846_level0_row6" class="row_heading level0 row6" >Savings</th>
#       <td id="T_ad846_row6_col0" class="data row6 col0" >R 0.0</td>
#       <td id="T_ad846_row6_col1" class="data row6 col1" >-</td>
#     </tr>
#   </tbody>
# </table>
# '******************************* WE RECOMMEND SHOPPING FROM CHECKERS ********************************'

# %%
page = fetch_html(WOOLWORTHS_SEARCH_URL+user_basket[0])
# Out:
# html downloaded successfully

# %%
product_div = page.find('div', class_='product-list__list')

# %%
products = product_div.find('div', class_='grid--flex')

# %%
product = products.findAll('div', class_='product-list__item')

# %%
len(product)
# Out:
# 60

# %%
df1 = pd.DataFrame.from_dict({'A': "Apple", 'B': 'Banana', 'C': 'Candle'}, orient='index')
df2 = pd.DataFrame.from_dict({'A': "Apple", 'B': 'Banana', 'C': 'Candle'}, orient='index')

df1_styler = df1.style.set_table_attributes("style='display:inline; margin:30px; text-align:center'").set_caption('Caption table 1')
df2_styler = df2.style.set_table_attributes("style='display:inline; margin:30px; text-align:center'").set_caption('Caption table 2')

display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)

# %%
search_result = fetch_html(CHECKERS_SEARCH_URL+'pork shoulder ribs')
# Out:
# html downloaded successfully

# %%
search_result
# Out:
# <!DOCTYPE html>
#  <html lang="en"> <head> <title> Search pork shoulder ribs | Checkers ZA</title> <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/> <meta content="pork,shoulder,ribs" name="keywords"/> <meta content="Search results for pork shoulder ribs on Checkers ZA" name="description"/> <meta content="index,follow" name="robots"/> <meta content="H16-wEJW_mSEwjpLumaZS5S_X0ZA3XjXWHiHaXGX_Ks" name="google-site-verification"> <meta content="a463fb8adf6a8f705e9fd4184ec03f2873cf1e99f68e38fb81b352aec15191c4" name="ahrefs-site-verification"> <meta content="1f5e98eddf473cf817f59bb620e71ad1" name="p:domain_verify"> <link href="/_ui/responsive/theme-checkers/images/favicon.ico" media="all" rel="shortcut icon" type="image/x-icon"/> <link href="https://www.checkers.co.za/search/all" rel="canonical"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/glyphicons-halflings-regular.woff" rel="preload" type="font/woff"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/glyphicons-halflings-regular.woff2" rel="preload" type="font/woff2"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/shoprite-icon.ttf?xo7m3y" rel="preload" type="font/ttf"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/bebasneue_bold-webfont.otf" rel="preload" type="font/otf"/> <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic,800,800italic" rel="stylesheet" type="text/css"> <link href="/_ui/responsive/theme-checkers/css/style.css" media="all" rel="stylesheet" type="text/css"> <link href="/_ui/addons/assistedservicestorefront/responsive/common/css/assistedservicestorefront.css" media="all" rel="stylesheet" type="text/css"> <link href="/_ui/addons/assistedservicestorefront/responsive/common/css/storeFinder.css" media="all" rel="stylesheet" type="text/css"> <link href="/_ui/addons/assistedservicestorefront/responsive/common/css/customer360.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/hybrisanalyticsaddon/responsive/common/css/hybrisanalyticsaddon.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/shopriteassistedservicestorefront/responsive/common/css/shopriteassistedservicestorefront.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/shopritemediacompression/responsive/common/css/shopritemediacompression.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/shopriteymktaddon/responsive/common/css/shopriteymktaddon.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/smarteditaddon/responsive/common/css/smarteditaddon.css" media="all" rel="stylesheet" type="text/css"/> <script>
# 		/*<![CDATA[*/
#
# 		var ACC = { config: {}, user: {} };
# 			ACC.config.contextPath = '';
# 			ACC.config.encodedContextPath = '';
# 			ACC.config.commonResourcePath = '\/_ui\/responsive\/common';
# 			ACC.config.themeResourcePath = '\/_ui\/responsive\/theme-checkers';
# 			ACC.config.siteResourcePath = '\/_ui\/responsive\/site-checkersZA';
# 			ACC.config.rootPath = '\/_ui\/responsive';
# 			ACC.config.CSRFToken = '06f4da8f-9307-4f77-a5d6-c901306397a7';
# 			ACC.config.recaptchaKey='';
# 			ACC.pwdStrengthVeryWeak = 'Very weak';
# 			ACC.pwdStrengthWeak = 'Weak';
# 			ACC.pwdStrengthMedium = 'Medium';
# 			ACC.pwdStrengthStrong = 'Strong';
# 			ACC.pwdStrengthVeryStrong = 'Very strong';
# 			ACC.pwdStrengthUnsafePwd = 'password.strength.unsafepwd';
# 			ACC.pwdStrengthTooShortPwd = 'Too short';
# 			ACC.pwdStrengthMinCharText = 'Minimum length is %d characters';
# 			ACC.accessibilityLoading = 'Loading... Please wait...';
# 			ACC.accessibilityStoresLoaded = 'Stores loaded';
# 			ACC.config.googleApiKey='AIzaSyDqAJj-wXYWuALzQnCjYoMc3tit8SaGYWc';
# 			ACC.config.googleApiVersion='3.7';
# 			ACC.config.googleMapIconPath='\/_ui\/responsive\/common\/images\/icons\/CheckersMapPin.svg';
# 			ACC.config.googleMapZoomInIconPath='\/_ui\/responsive\/common\/images\/icons\/ZoomIn.svg';
# 			ACC.config.googleMapZoomOutIconPath='\/_ui\/responsive\/common\/images\/icons\/ZoomOut.svg';
# 			ACC.config.googleLoadDirections='';
# 			ACC.config.asmLoggedIn='false';
# 			ACC.config.verifyEmail='';
# 			ACC.config.currentCurrencyIsoCode = 'ZAR';
# 			ACC.user.customerId='00000000';
# 			ACC.user.loggedIn=false;
#
#
# 			ACC.autocompleteUrl = '\/search\/autocompleteSecure';
#
#
# 			ACC.config.loginUrl = '\/login';
#
#
# 			ACC.config.authenticationStatusUrl = '\/authentication\/status';
#
#
# 		/*]]>*/
# 	</script> <script>
# 	/*<![CDATA[*/
# 	ACC.addons = {};	//JS namespace for addons properties
#
#
# 		ACC.addons['shopriteymktaddon'] = [];
#
# 		ACC.addons['shopriteassistedservicestorefront'] = [];
#
# 		ACC.addons['smarteditaddon'] = [];
#
# 		ACC.addons['shopritemediacompression'] = [];
#
# 		ACC.addons['assistedservicestorefront'] = [];
#
# 				ACC.addons['assistedservicestorefront']['asm.timer.min'] = 'min';
#
# 		ACC.addons['eventtrackingwsaddon'] = [];
#
# 		ACC.addons['hybrisanalyticsaddon'] = [];
#
# 	/*]]>*/
# </script> <script defer="" src="/_ui/shared/js/generatedVariables.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery-3.6.0.min.js"></script> <script defer="" src="/_ui/responsive/common/js/enquire.min.js"></script> <script defer="" src="/_ui/responsive/common/js/Imager.min.js"></script> <script defer="" src="/_ui/responsive/common/js/purify.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.blockUI-2.66.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.colorbox-min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.form.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.hoverIntent.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.pstrength.custom-1.2.0.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.syncheight.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.tabs.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery-ui-1.12.1.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.zoom.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/owl.carousel.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.tmpl-1.0.0pre.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.currencies.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.waitforimages.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.slideviewer.custom.1.2.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.validate.js"></script> <script defer="" src="/_ui/responsive/common/js/js.cookie.min.js"></script> <script defer="" src="/_ui/responsive/common/js/sharer.js"></script> <script defer="" src="/_ui/responsive/common/js/drift.js"></script> <script defer="" src="/_ui/responsive/common/js/pinch-zoom.js"></script> <script defer="" src="/_ui/responsive/common/bootstrap/js/bootstrap.js"></script> <script defer="" src="/_ui/responsive/common/js/cleave.js"></script> <script defer="" src="/_ui/responsive/common/js/moment.min.js"></script> <script defer="" src="/_ui/responsive/common/js/bootstrap-datetimepicker.min.js"></script> <script defer="" src="/_ui/responsive/common/js/handlebars.min.js"></script> <script defer="" src="/_ui/responsive/common/js/typeahead.bundle.js"></script> <script defer="" src="/_ui/responsive/common/js/datatables.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.daterangepicker.js"></script> <script defer="" src="/_ui/responsive/common/js/tiny-slider.js"></script> <script defer="" src="/_ui/responsive/common/js/swiper.js"></script> <script defer="" src="/_ui/responsive/common/js/html2canvas.js"></script> <script defer="" src="/_ui/responsive/common/js/jspdf.umd.min.js"></script> <script defer="" src="/_ui/responsive/common/js/localization/messages.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.track.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.shopriteutils.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.localization.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.common.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.address.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.autocomplete.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.carousel.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.ajaxcarousel.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.masthead.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.savingsandslips.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.ajaxcomponent.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.cart.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.cartitem.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.checkout.js"></script> <sc ...
#     w[l] = w[l] || [];
#     w[l].push({
#         'gtm.start':
#
#             new Date().getTime(), event: 'gtm.js'
#     });
#     var f = d.getElementsByTagName(s)[0],
#
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
#
# })(window, document, 'script', 'dataLayer', 'GTM-597TTQ');</script> <script defer="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script> <script defer="" type="text/javascript">
#         window.googletag = window.googletag || {cmd: []};
#         googletag.cmd.push(function () {
#             const mapping1 = googletag.sizeMapping()
#                 .addSize([1280, 0], [[970, 90]])
#                 .addSize([760, 0], [[728, 90]])
#                 .addSize([0, 0], [[320, 100], [320, 50]])
#                 .build();
#
#             googletag.defineSlot("/22346593009/checkers-web/search_landing", [[970, 90], [728, 90], [320, 100], [320, 50]], "gpt-ad-1")
#                 .setTargeting("pos", ["1"])
#                 .defineSizeMapping(mapping1)
#                 .addService(googletag.pubads());
#
#             googletag.defineSlot("/22346593009/checkers-web/search_landing", [[970, 90], [728, 90], [320, 100], [320, 50]], "gpt-ad-2")
#                 .setTargeting("pos", ["2"])
#                 .defineSizeMapping(mapping1)
#                 .addService(googletag.pubads());
#
#             googletag.pubads().setTargeting("prod_code", "");
#             googletag.pubads().setTargeting("tag", "");
#             googletag.pubads().setTargeting("search", "");
#             googletag.pubads().setTargeting("serve_size", "");
#             googletag.pubads().setTargeting("recipe_type", "");
#             googletag.pubads().setTargeting("price", "");
#             googletag.pubads().setTargeting("prep_time", "");
#             googletag.pubads().setTargeting("no_ingredients", "");
#             googletag.pubads().setTargeting("mat_type", "");
#             googletag.pubads().setTargeting("ingredients", "");
#             googletag.pubads().setTargeting("diet", "");
#             googletag.pubads().setTargeting("dc_seg", "");
#             googletag.pubads().setTargeting("cat", "");
#             googletag.pubads().setTargeting("brand", "");
#             googletag.pubads().setTargeting("art_guar", "");
#             googletag.pubads().setTargeting("allegens", "");
#             googletag.pubads().setTargeting("user_type", "anonymous");
#             googletag.pubads().collapseEmptyDivs();
#             googletag.pubads().setCentering(true);
#             googletag.pubads().enableLazyLoad();
#             googletag.enableServices();
#         });
#     </script> <script defer="">
#     window.lazySizesConfig = window.lazySizesConfig || {};
#     window.lazySizesConfig.srcAttr = 'data-original-src';
#     window.lazySizesConfig.srcsetAttr = 'data-original-srcset';
# </script> <script defer="" src="/_ui/responsive/common/js/lazysizes.min.js"></script> <script defer="" src="/_ui/responsive/common/js/rbm.checkersZA.js"></script> <script defer="" src="/_ui/responsive/common/js/_autoload.js"></script> </link></link></link></link></meta></meta></meta></head> <body class="page-search-landing pageType-ContentPage template-pages-search-searchLandingPage pageLabel-search-landing smartedit-page-uid-search-landing smartedit-page-uuid-eyJpdGVtSWQiOiJzZWFyY2gtbGFuZGluZyIsImNhdGFsb2dJZCI6ImNoZWNrZXJzWkFDb250ZW50Q2F0YWxvZyIsImNhdGFsb2dWZXJzaW9uIjoiT25saW5lIn0= smartedit-catalog-version-uuid-checkersZAContentCatalog/Online language-en"> <span class="hidden js-default-store-selected" data-default-store-selected-without-geo-info="true" data-selected-store-closed=""></span> <googletagmanager:iframe></googletagmanager:iframe> <main data-currency-iso-code="ZAR"> <a class="skiptocontent" data-role="none" href="#skip-to-content">Skip to content</a> <a class="skiptonavigation" data-role="none" href="#skiptonavigation">Skip to navigation</a> <div class="yCmsContentSlot"> <div class="js-offers-header-component" data-base-url="/view/LProOffersHeaderComponentController/ajax/content" data-component-id="lProOffersHeaderComponent"></div> </div><header class="header js-mainHeader"> <div class="hidden-xs hidden-sm js-secondaryNavAccount collapse" id="accNavComponentDesktopOne"> <ul class="nav__links"></ul> </div> <div class="hidden-xs hidden-sm js-secondaryNavCompany collapse" id="accNavComponentDesktopTwo"> <ul class="nav__links js-nav__links"></ul> </div> <a id="skiptonavigation"></a> <div class="wrap"> <div class="header__top"> <button aria-label="Menu" class="header__menu-button js-toggle-sm-navigation visible-xs"> <i class="shoprite-icon-hamburger-menu"></i> </button> <div class="yCmsComponent header__logo"> <div class="banner__component simple-banner aspect-ratio-box" style="padding-top:15.540541%"> <a href="/"> <img alt="Checkers ZA" class="lazyload" data-original-src="/medias/checkers-logo.svg?context=bWFzdGVyfGltYWdlc3w2NTY2fGltYWdlL3N2Zyt4bWx8aW1hZ2VzL2g5ZS9oN2MvODg2NTY1MDgwMjcxOC5zdmd8MTQwMWY4NTIwMmI0NDZhM2RhMTI3MTYxYzE2ZDkwOWMyNDUwMDYyYjRjZTkwOTE5NmM2NWI1OGM4OGVjOWI2Yg" title="Checkers ZA"/> </a> </div> </div><div class="yCmsComponent header-nav-links-component"> <div class="header-nav-links-top header-nav-links-wrapper hidden-sm hidden-xs"> <span class="header-nav-links"> <a class="" href="/" target="_self" title="Home">Home</a> </span> <span class="header-nav-links"> <a class="" href="/store-finder" target="_self" title="Find a Store">Find a Store</a> </span> </div> </div><div class="header__top__links"> <div class="header__top__links__promoAlert"> <div class="promo-alerts js-promo-alerts-reload-page" data-sign-in-url="/promo-alerts/username-content"> <div class="promo-alerts__menu"> <a class="promo-alerts__menu__link" href="/my-account/promo-alerts" title="Promo Alerts"><span class="text">Promo Alerts</span></a> <div class="promo-alerts__submenu logout js-promo-alerts-flyout-content" data-verify-email-url="/promo-alerts/verify-email"> <div class="js-promo-alerts-success-message"></div> <div class="promo-alerts__submenu-button visible-xs visible-sm visible-md visible-lg"> <button class="close-button js-flyout-close" type="button"><i aria-hidden="true" class="icon shoprite-icon-close"></i></button> </div> <div class="promo-alerts-logout"> <div class="promo-alerts-notifications"> <div class="promo-alerts-notifications__image"> <img alt="" src="/_ui/responsive/common/images/promo-alerts/notifications-image.png"/> </div> <h3 class="promo-alerts-notifications__title">Never miss another great deal with promo alerts!</h3> <div class="promo-alerts-notifications__steps"> <div class="step"> <div class="step__image"> <img alt="" src="/_ui/responsive/common/images/promo-alerts/logout-info-image1.png"/> </div> <div class="step__text">Simply activate Promo Alerts on <strong>products you love to buy.</strong></div> </div>  ...
# @media (max-width: 636px){
# .promo-alerts .product__buttons {
#     position: static;
# }
# .promo-alerts .product {
#     -ms-flex-direction: row;
#     flex-direction: row;
#
# .promo-alerts .product__image {
#     position: static;
#
# }
# }
# </style></div><div class="header__search header__search--mobile visible-xs"></div> </div> <div class="header__your-store hidden-xs"> <div class="header__your-store__content js-toggle-store-finder store-finder-wrap"> <div class="header__your-store__icon"> <i class="shoprite-icon-select-a-store"></i> </div> <div class="header__your-store__select"> <span>Default Store</span> <span class="header__your-store__name">Checkers Mall Of The North</span> <i aria-hidden="true" class="shoprite-icon-dropdown-arrow"></i> </div> <div class="header-store-wrapper header-store-wrapper--desktop"> <div class="yCmsComponent"> <div class="js-store-search-filed"> <div class="store-finder-filters-overlay js-store-finder-filters-overlay"></div> <div class="store-search-field"> <span class="js-close-btn visible-xs">×</span> <p class="store-text-bold"> Find a store</p> <div class="store-finder-search-wrap form-section__row"> <input aria-label="Enter a city, suburb or postcode" class="js-store-finder-input js-search-store-input form-section__input" id="storeFinderInput" name="storeFinderInput" placeholder="Enter a city, suburb or postcode" type="text"/> <span aria-hidden="true" class="store-search-input-clear js-store-search-input-clear"><i class="shoprite-icon-clear"></i></span> <i class="shoprite-icon-search store-search-icon"></i> <i class="icon shoprite-icon-filter store-filter-icon js-show-store-filters"></i> </div> <div class="store-finder-location-wrap"> <a class="store-finder-location-btn" href="#" id="findStoresNearMe"> <i class="icon shoprite-icon-use-location"></i> Find a store near me</a> </div> <div class="store-finder-filters js-filter-options hidden" data-filters-id="filterOptionsStoreFinderHeaderSearchComponent"> <div class="store-finder-filters__table"> <button class="store-finder-filters__close js-show-store-filters" type="button"> <i aria-hidden="true" class="shoprite-icon-close"></i> </button> <div class="store-finder-filters__title"> Filter by</div> <div class="store-finder-filters__table__row"> <div class="sr-switch"> <label class="control-label sr-switch__label" for="filterOptionsStoreFinderHeaderSearchComponentstoreFilter0"> <input class="js-store-filter" data-code="LIQUORSHOP" id="filterOptionsStoreFinderHeaderSearchComponentstoreFilter0" type="checkbox"/> <div class="sr-switch__slider"></div> <span class="sr-switch__text">LiquorShop</span> </label> </div> </div> <div class="store-finder-filters__table__row"> <div class="sr-switch"> <label class="control-label sr-switch__label" for="filterOptionsStoreFinderHeaderSearchComponentstoreFilter1"> <input class="js-store-filter" data-code="MEDIRITE" id="filterOptionsStoreFinderHeaderSearchComponentstoreFilter1" type="checkbox"/> <div class="sr-switch__slider"></div> <span class="sr-switch__text">Medirite</span> </label> </div> </div> <div class="store-finder-filters__table__row"> <div class="sr-switch"> <label class="control-label sr-switch__label" for="filterOptionsStoreFinderHeaderSearchComponentstoreFilter2"> <input class="js-store-filter" data-code="LITTLEME" id="filterOptionsStoreFinderHeaderSearchComponentstoreFilter2" type="checkbox"/> <div class="sr-switch__slider"></div> <span class="sr-switch__text">Little Me</span> </label> </div> </div> <div class="store-finder-filters__table__row"> <div class="sr-switch"> <label class="control-label sr-switch__label" for="filterOptionsStoreFinderHeaderSearchComponentstoreFilter3"> <input class="js-store-filter" data-code="HYPER" id="filterOptionsStoreFinderHeaderSearchComponentstoreFilter3" type="checkbox"/> <div class="sr-switch__slider"></div> <span class="sr-switch__text">Hyper</span> </label> </div> </div> </div> <div class="store-finder-filters__button"> <button class="store-finder-filters__button-filter js-filter-stores-btn" disabled="" id="filterStoresBtn" type="button"> Show results</button> <button class="store-finder-filters__button-reset js-reset-store-filters-btn" type="button"> Reset</button> </div> </div> </div> <div class="pre ...
# .header__top .header-nav-links-component {
# max-width: 181px;
# }
# </style></div><nav class="navigation navigation--bottom js_navigation--bottom js-enquire-offcanvas-navigation" role="navigation"> <div class="visible-xs"> <div class="login-mobile-leftside"> <div class="login-mobile-top"> <button class="close-sm-navigation js-toggle-sm-navigation btn close-icon-mobile" type="button"> <i class="shoprite-icon-close"></i> </button> <div class="top centered"> <span class="title">Welcome Back</span> <a class="btn-custom btn-green link-ga-register-label" data-galabel="Nav Menu" href="/login"> Sign In </a> <p> <small>New to Checkers?  <a class="custom-link link-ga-register-label" data-galabel="Nav Menu" href="/login/register"> Sign Up </a> </small> </p> </div> </div> </div> </div> <div class="js-header-nav-links-top"></div> <div class="navigation__overflow"> <ul class="nav__links nav__links--products js-offcanvas-links"> <li class="auto nav__links--primary browse-products nav__links--primary-has__sub js-enquire-has-sub nav-with-chevron"> <i class="shoprite-icon-hamburger-menu hidden-xs"></i> <span class="yCmsComponent nav__link js_nav__link" id="BrowseProductsNavNodeEntry"> <a href="/c-2256/All-Departments" title="Browse Products">Browse Products</a></span><span class="nav__link--drill__down js_nav__link--drill__down shoprite-icon-dropdown-expand"></span> <div class="sub__navigation js_sub__navigation col-lg-12"> <div class="row sub-navigation-row"> <div class="js-subnav-border subnav-border"></div> <div class="sub-navigation-section col-md-3 col BrowseProductsNavNode" col="1"> <div class="sub-navigation-section"> <ul class="sub-navigation-list has-title"> <li class="nav__link--secondary title-nav view-all"> <a class="pull-right hidden-xs" href="/c-2256/All-Departments">View All</a> <h3 class="title">All Departments</h3> </li> <li class="nav__link--secondary" id="food"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2413/All-Departments/Food" title="Food">Food</a> </li> <li class="nav__link--secondary" id="drinks"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2257/All-Departments/Drinks" title="Drinks">Drinks</a> </li> <li class="nav__link--secondary" id="household"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2721/All-Departments/Household" title="Household">Household</a> </li> <li class="nav__link--secondary" id="health_and_beauty"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2748/All-Departments/Health-and-Beauty" title="Health &amp; Beauty">Health &amp; Beauty</a> </li> <li class="nav__link--secondary" id="baby"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2806/All-Departments/Baby" title="Baby">Baby</a> </li> <li class="nav__link--secondary" id="sport"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2807/All-Departments/Sport" title="Sport">Sport</a> </li> <li class="nav__link--secondary" id="outdoor"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2814/All-Departments/Outdoor" title="Outdoor">Outdoor</a> </li> <li class="nav__link--secondary" id="pets"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2820/All-Departments/Pets" title="Pets">Pets</a> </li> <li class="nav__link--secondary" id="toys"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2821/All-Departments/Toys" title="Toys">Toys</a> </li> <li class="nav__link--secondary" id="clothing_and_footwear"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2823/All-Departments/Clothing-and-Footwear" title="Clothing &amp; Footwear">Clothing &amp; Footwear</a> </li> <li class="nav__link--secondary" id="electronics"> <span class="shoprite-icon-chevron-right left-nav-icon"></span> <a href="/c-2824/All-Departments/Electronics" title="Electronics">Electronics</a> </li> <li class="nav__link--secondary" id="gifts"> <span class="shoprite-icon-chevron-right left- ...
#         .responsive-aspect-ratio-box-XtraSavingsHeaderSignedOutBanner {
#
#                             padding-top: 15.068493%;
#
#                 }
#                         @media (max-width: 1280px) {
#                             .responsive-aspect-ratio-box-XtraSavingsHeaderSignedOutBanner {
#
#                             padding-top: 15.068493%;
#
#                 }
#                         }
#
#                         @media (max-width: 1024px) {
#                             .responsive-aspect-ratio-box-XtraSavingsHeaderSignedOutBanner {
#
#                             padding-top: 19.730942%;
#
#                 }
#                         }
#
#                         @media (max-width: 636px) {
#                             .responsive-aspect-ratio-box-XtraSavingsHeaderSignedOutBanner {
#
#                             padding-top: 68.888885%;
#
#                 }
#                         }
#                     </style> <div class="simple-responsive-banner-component-container"> <div class="simple-banner banner__component--responsive full-mobile-image responsive-aspect-ratio-box-XtraSavingsHeaderSignedOutBanner aspect-ratio-box"> <a href="/xtra-savings"> <picture> <source data-original-srcset="/medias/header-signed-out-mobile.png?context=bWFzdGVyfGltYWdlc3wxNjQ1OHxpbWFnZS9wbmd8aW1hZ2VzL2hmOC9oZjEvOTI5OTQ5NDczMTgwNi5wbmd8OTE3OTA5N2QxYmNkODJiYTIyMTk4Mzg0OGYzZTYwZmFhMWQxMGRjMzc5ODg1MzNkYzczOGQzMTJjMmI3OWFhZg" media="(max-width: 636px)" srcset="/medias/lqi-header-signed-out-mobile.png?context=bWFzdGVyfGltYWdlc3wxNDU2fGltYWdlL3BuZ3xpbWFnZXMvaGU3L2g2Mi85Mjk5NDk0ODk1NjQ2LnBuZ3xkZDU2ZWRhZGM0MjVmZTJmYTVjNGQyNWJlNmM0ZGMwMjRhNDg0YTc4ZmRkZWE5MWMwYjhjMzUzOWQzYWNiYjIx"/> <source data-original-srcset="/medias/header-signed-out-tablet.png?context=bWFzdGVyfGltYWdlc3wyNDA4NXxpbWFnZS9wbmd8aW1hZ2VzL2gwMi9oZGMvOTI5OTQ5NDc5NzM0Mi5wbmd8ZmUwOTNhNDU3ZmMzNTFkZTRjMmNmYmZkNGViZDRkN2Y4Y2EwZWUyOWZmYWNlMjNlNTIzNWYwNjgyYjk5YTA3MQ" media="(max-width: 1024px)" srcset="/medias/lqi-header-signed-out-tablet.png?context=bWFzdGVyfGltYWdlc3w4NTB8aW1hZ2UvcG5nfGltYWdlcy9oZTQvaDEzLzkyOTk0OTQ5OTM5NTAucG5nfGVlMWE1YTU1NjM5OGMwMDAzZTRjMGViYWI0MTgyMzVkZWMzYTkyZWYzMzY2Yzc2MTcyYzQzZGFhMjY3MWQ0ZGY"/> <source data-original-srcset="/medias/header-signed-out-desktop.png?context=bWFzdGVyfGltYWdlc3wyOTA1MHxpbWFnZS9wbmd8aW1hZ2VzL2hkMC9oMmUvOTI5OTQ5NDc2NDU3NC5wbmd8MDJjZjQ5Njg4YjBkYmJmMzI2YzQxOWZmY2U0NmY5MWI2OGQzODZkNjQyNzFjMGYzMTA4YjM2MjQ0Y2Y1YWU3MQ" media="(max-width: 1280px)" srcset="/medias/lqi-header-signed-out-desktop.png?context=bWFzdGVyfGltYWdlc3w3ODh8aW1hZ2UvcG5nfGltYWdlcy9oMWEvaGE0LzkyOTk0OTUwMjY3MTgucG5nfDg0OWUxOWIyZTFkOTM2NmNmMjY5Y2IyMWNlOTlmMjlmZDhiNjU4YjU1NDY1YTRlYjAyM2U4Y2JjZTVmMzcwMTU"/> <source data-original-srcset="/medias/header-signed-out-widescreen.png?context=bWFzdGVyfGltYWdlc3wyOTA1MHxpbWFnZS9wbmd8aW1hZ2VzL2gzMS9oYWQvOTI5OTQ5NDY5OTAzOC5wbmd8Mzk0MjllZDdmYjdhNzFlZGE1NTk2NTc3NWEwNTk5YzYyZDE1N2JjNTZkM2I1YjIyMmQ1ZTk3MjkzZDMzNjU4OQ" media="(max-width: 1920px)" srcset="/medias/lqi-header-signed-out-widescreen.png?context=bWFzdGVyfGltYWdlc3w3ODh8aW1hZ2UvcG5nfGltYWdlcy9oZDEvaDM0LzkyOTk0OTUwOTIyNTQucG5nfDgxM2I5ZWQ2YTUxMjZiMDQzNzE5ZTNmYmYzYjZlM2E2OTk3MzljMmI3ZDA4NmJhY2M0ZjY5NzVhNDU0NjQ5OTk"/> <img alt="Your Xtra Savings" class="lazyload" data-original-src="/medias/header-signed-out-widescreen.png?context=bWFzdGVyfGltYWdlc3wyOTA1MHxpbWFnZS9wbmd8aW1hZ2VzL2gzMS9oYWQvOTI5OTQ5NDY5OTAzOC5wbmd8Mzk0MjllZDdmYjdhNzFlZGE1NTk2NTc3NWEwNTk5YzYyZDE1N2JjNTZkM2I1YjIyMmQ1ZTk3MjkzZDMzNjU4OQ" src="/medias/lqi-header-signed-out-widescreen.png?context=bWFzdGVyfGltYWdlc3w3ODh8aW1hZ2UvcG5nfGltYWdlcy9oZDEvaDM0LzkyOTk0OTUwOTIyNTQucG5nfDgxM2I5ZWQ2YTUxMjZiMDQzNzE5ZTNmYmYzYjZlM2E2OTk3MzljMmI3ZDA4NmJhY2M0ZjY5NzVhNDU0NjQ5OTk"> </img></picture> </a> </div> </div> </div> </div> </div> </div> </div> <input class="js-geoPointLatitude" name="geoPointLatitude" type="number" value="-23.87389"/> <input class="js-geoPointLongitude" name="geoPointLongitude" type="hidden" value="29.51"/> </header> <div class="breadcrumb-section"> <div class="wrap"> </div> </div> <div class="yCmsContentSlot wrap"> <div class="results result-for-search"> <div class="wrap bottom-header-padding"> <span class="top-heading-text-result js-landing-total-result">399</span> <span class="top-heading-text">results for</span> <span class="top-heading-text-result">"pork shoulder ribs"</span> </div> </div> </div><a id="skip-to-content"></a> <div class="main__inner-wrapper wrap"> <div id="gpt-ad-1"> <script type="text/javascript">
#         googletag.cmd.push(function () {
#             googletag.display("gpt-ad-1");
#         });
#     </script> </div> <div class="search-landing"> <div class="yCmsContentSlot"> <div class="yCmsComponent"> <div class="search-landing__block search-landing__block--products js-search-landing-product-content"> <div class="search-landing__block__header"> <span class="js-total-products" data-total="233">Products (233)</span> <div class="search-landing__actions"> <div class="search-landing__filter"> <button class="button js-search-landing-product-show-facets" data-select-refinements-title="Select Refinements"> <i class="icon shoprite-icon-filter"></i> Filter</button> </div> <form action="/search"> <input name="q" type="hidden" value="pork shoulder ribs"> <input class="button" type="submit" value="See All"> </input></input></form> </div> </div> <div class="row"> <div class="col-sm-12 col-md-3"> <div class="hidden-sm hidden-xs hidden-md product__facet js-product-facet" data-type-code="Product" id="product-facet"> <input name="currentSearchQuery" type="hidden" value="pork shoulder ribs:searchRelevance:browseAllStoresFacetOff:browseAllStoresFacetOff"> <div class="facet-filter-actions hidden-lg"> <span class="facet-close-btn shoprite-icon-close"></span> <span class="filter-text">Filter</span> <button class="js-landing-product-refine-close pull-right">Done</button> </div> <div class="categories-sidebar"> <div class="categories-sidebar categories-sidebar--special"> <div class="facet js-facet product-categories"> <div aria-labelledby="collapseListGroupHeading1" class="panel-collapse collapse in categories" id="xtraSavingInSites" role="tabpanel"> <ul class="facet__list js-facet-list"> <li> <div class="special-facet"> Xtra Savings Only <form action="#" data-ajax-url="/search/all/refine-products?q=pork+shoulder+ribs%3AsearchRelevance%3AxtraSavingInSites%3A57861%3AxtraSavingInSites%3APSGN%3AbrowseAllStoresFacetOff%3AbrowseAllStoresFacetOff" method="get"> <input name="q" type="hidden" value="pork shoulder ribs:searchRelevance:xtraSavingInSites:57861:xtraSavingInSites:PSGN:browseAllStoresFacetOff:browseAllStoresFacetOff"> <label class="switch"> <input class="js-search-landing-product-facet-checkbox js-special-facet" type="checkbox" value="xtraSavingInSites:57861:xtraSavingInSites:PSGN"/> <span class="slider round"></span> </label> </input></form> </div> </li> </ul> </div> <div aria-labelledby="collapseListGroupHeading1" class="panel-collapse collapse in categories" id="regularSaveInSites" role="tabpanel"> <ul class="facet__list js-facet-list"> <li> <div class="special-facet"> Specials Only <form action="#" data-ajax-url="/search/all/refine-products?q=pork+shoulder+ribs%3AsearchRelevance%3AregularSaveInSites%3A57861%3AregularSaveInSites%3APSGN%3AbrowseAllStoresFacetOff%3AbrowseAllStoresFacetOff" method="get"> <input name="q" type="hidden" value="pork shoulder ribs:searchRelevance:regularSaveInSites:57861:regularSaveInSites:PSGN:browseAllStoresFacetOff:browseAllStoresFacetOff"> <label class="switch"> <input class="js-search-landing-product-facet-checkbox js-special-facet" type="checkbox" value="regularSaveInSites:57861:regularSaveInSites:PSGN"/> <span class="slider round"></span> </label> </input></form> </div> </li> </ul> </div> </div> </div> <div class="categories-sidebar categories-sidebar--special categories-sidebar--browse-all js-facet-form"> <div class="browse-all-stores"> <span class="title">Browse All Stores</span> <span class="text">Show products and specials from all Checkers stores.</span> <form action="#" data-ajax-url="/search/all/refine-products?q=pork+shoulder+ribs%3AsearchRelevance%3AbrowseAllStoresFacetOff%3AbrowseAllStoresFacetOff%3AbrowseAllStoresFacet%3AbrowseAllStoresFacet" method="get"> <input name="q" type="hidden" value="pork shoulder ribs:searchRelevance:browseAllStoresFacetOff:browseAllStoresFacetOff:browseAllStoresFacet:browseAllStoresFacet"> <label class="switch"> <input class="js-search-landing-product-facet-checkbox js-special-facet" type="checkbox"/> <span class="slider round"></span> </label> </input></form> </div ...
#         googletag.cmd.push(function () {
#             googletag.display("gpt-ad-2");
#         });
#     </script> </div> </div> <footer class="footer"> <div class="wrap"> <div class="footer__top"> <div class="footer__top__col footer__top__col--accordion js-footer-col-accordion"> <h4 class="footer__title">Your Profile</h4> <ul class="footer__top__col__content"> <li class="yCmsComponent"> <a class="link-ga-register-label link-ga-register-label--footer" href="/login/register" title="Sign Up">Sign Up</a></li><li class="yCmsComponent"> <a href="/store-finder" title="Find a Store">Find a Store</a></li><li class="yCmsComponent"> <a class="link-ga-register-label link-ga-register-label--footer" href="/login" title="Sign In">Sign In</a></li></ul> </div> <div class="footer__top__col footer__top__col--customer-service footer__top__col--accordion js-footer-col-accordion"> <h4 class="footer__title">Customer Service</h4> <ul class="footer__top__col__content"> <li class="yCmsComponent"> <div class="content cms-paragraph"><div class="footer__whatsapp"><a class="footer__whatsapp__content" href="https://wa.me/27872405385"><img class="footer__whatsapp__logo" src="/_ui/responsive/common/images/whatsapp-logo.png" srcset="/_ui/responsive/common/images/whatsapp-logo.png 1x, /_ui/responsive/common/images/whatsapp-logo-2x.png 2x, /_ui/responsive/common/images/whatsapp-logo-3x.png 3x"><span class="footer__whatsapp__text">Sign Up for Xtra Savings on WhatsApp by adding <strong>087 240 5385</strong> to your contacts.</span><div class="footer__whatsapp__arrow"><i class="shoprite-icon-chevron-right"></i></div></img></a></div></div></li><li class="yCmsComponent"> <div class="content cms-paragraph"><p class="footer__customer-care-info">Customer Care: <a href="tel:0800010709">0800 01 07 09</a></p></div></li><li class="yCmsComponent"> <a href="https://www.checkers.co.za/help-centre" title="Frequently Asked Questions">Frequently Asked Questions</a></li><li class="yCmsComponent"> <a href="/help-centre/contact-us" title="Contact Us">Contact Us</a></li><li class="yCmsComponent"> <a href="/about-us" title="About Us">About Us</a></li><li class="yCmsComponent"> <a href="https://www.shopriteholdings.co.za/careers.html" target="_blank" title="Careers">Careers</a></li><li class="yCmsComponent"> <a href="https://www.rainmakermedia.co.za/" target="_blank" title="Advertise With Us">Advertise With Us</a></li><li class="yCmsComponent"> <div class="content cms-paragraph"><p class="footer__customer-care-info">Xtra Savings Support: <a href="tel:0800333385">0800 33 33 85</a></p></div></li></ul> </div> <div class="footer__top__col footer__top__col--xtra-savings footer__top__col--accordion js-footer-col-accordion"> <h4 class="footer__title">Xtra Savings</h4> <ul class="footer__top__col__content"> <li> <div class="yCmsComponent footer__xs-banner"> <div class="banner__component simple-banner full-mobile-image aspect-ratio-box" style="padding-top:26.415094%"> <a href="/xtra-savings"> <img alt="Xtra saving" class="lazyload" data-original-src="/medias/xtra-saving-banner-footer.png?context=bWFzdGVyfGltYWdlc3wxODY4MHxpbWFnZS9wbmd8aW1hZ2VzL2g4NS9oZGQvODkyNzE4Njk0NDAzMC5wbmd8NzJmZWRkZTEzZmE2Y2EzMzVlNTIyNmNhNDU4YjQ3ZWI1YWFlMzBmNDdkZGUxOTQxMmFhNzJlMzA3ZjNhNWVlYw" title="Xtra saving"/> <img class="low-quality-img" src="/medias/lqi-xtra-saving-banner-footer.png?context=bWFzdGVyfGltYWdlc3wxNzI5fGltYWdlL3BuZ3xpbWFnZXMvaGM4L2gxZC85MDgxMDU5MDQ5NTAyLnBuZ3w2MWI2ODhhOWIxYWZiNWQ0MDAwY2JmNmYxMzg1NzZhMmNjZGY1ZTlhZDQ5MTM0ODNhN2VkYTJiNmFjYjc3NDhl"/></a> </div> </div></li> <li class="yCmsComponent"> <a href="https://www.checkers.co.za/all-xtra-savings" title="View All Xtra Savings">View All Xtra Savings</a></li><li class="yCmsComponent"> <a class="link-ga-register-label link-ga-register-label--xs" href="/my-account/manage-loyalty-card/" title="Link Your Card">Link Your Card</a></li><li class="yCmsComponent"> <a href="/xtra-savings" title="Xtra Savings Benefits">Xtra Savings Benefits</a></li><li class="yCmsComponent"> <a href="https://www.checkers.co.za/Xtra-Savings-TermsAndConditions" title="Xtra Savings T ...
#     var inputs = document.querySelectorAll(".form-section__input");
#
#     if (inputs.length > 0) {
#         inputs.forEach(function (element) {
#             element.addEventListener("input", function () {
#                 if (element.value !== "") {
#                     element.classList.add("used");
#                 } else {
#                     element.classList.remove("used");
#                 }
#             });
#
#             if (element.value !== "") {
#                 element.classList.add("used");
#             } else {
#                 element.classList.remove("used");
#             }
#         });
#     }
# </script><form name="accessiblityForm"> <input id="accesibility_refreshScreenReaderBufferField" name="accesibility_refreshScreenReaderBufferField" type="hidden" value=""/> </form> <div aria-live="polite" aria-relevant="text" class="skip" id="ariaStatusMsg" role="status"></div> <script type="text/javascript">
# 	var analyticsConfig;
# 	if(typeof ACC != 'undefined'){
# 		analyticsConfig = ACC.addons.hybrisanalyticsaddon;
# 	}else{
# 		analyticsConfig = ACCMOB.addons.hybrisanalyticsaddon;
# 	}
# 	var piwikTrackerUrl = "https:\/\/www.checkers.co.za\/events"; // Use Piwik HTTPS Endpoint by default
# 	var piwikSiteId = "1";
# 	var sessionId = "7b3262f7-404c-4995-910f-4698bc5b8c4d";
#
# 	if(location.protocol != 'https:')	// if the current page does not use https protocol, use the normal HTTP endpoint:
# 	{
# 		piwikTrackerUrl = "http:\/\/www.checkers.co.za\/events";
# 	}
#
# 	var tracker = Piwik.getAsyncTracker(piwikTrackerUrl, piwikSiteId);
#
# 	tracker.setTrackerUrl(piwikTrackerUrl);
# 	tracker.setSiteId(piwikSiteId);
# 	tracker.setRequestMethod('POST');
# 	tracker.setRequestContentType('application/json; charset=UTF-8');
#
# 	var processPiwikRequest = (function (request) {
# 		try {
# 			var pairs = request.split('&');
#
# 			var requestParametersArray = {};
# 			for (index = 0; index < pairs.length; ++index) {
# 				var pair = pairs[index].split('=');
# 				requestParametersArray[pair[0]] = decodeURIComponent(pair[1] || '');
# 			}
# 			requestParametersArray['sessionId'] = sessionId;
#
# 			return JSON.stringify(requestParametersArray);
# 		} catch (err) {
# 			return request;
# 		}
# 	});
#
# 	tracker.setCustomRequestProcessing(processPiwikRequest);
#
# 	var hybrisAnalyticsPiwikPlugin = (function() {
# 		function _getEventtypeParam(suffix) { return '&eventtype=' + suffix; }
# 		function ecommerce() { return _getEventtypeParam("ecommerce"); }
# 		function event() { return _getEventtypeParam("event"); }
# 		function goal() { return _getEventtypeParam("goal"); }
# 		function link() { return _getEventtypeParam("link"); }
# 		function load() { return _getEventtypeParam("load"); }
# 		function log() { return _getEventtypeParam("log"); }
# 		function ping() { return _getEventtypeParam("ping"); }
# 		function run() { return _getEventtypeParam("run"); }
# 		function sitesearch() { return _getEventtypeParam("sitesearch"); }
# 		function unload() { return _getEventtypeParam("unload"); }
#
# 		return {
# 			ecommerce: ecommerce,
# 			event : event,
# 			goal : goal,
# 			link : link,
# 			load : load,
# 			log : log,
# 			ping: ping,
# 			sitesearch : sitesearch,
# 			unload : unload
# 		};
# 	})();
# 	tracker.addPlugin('hybrisAnalyticsPiwikPlugin', hybrisAnalyticsPiwikPlugin);
# 	// Hybris Analytics specifics - END
#
#
#
# 			//Otherwise default to page view event
# 			tracker.trackPageView('ViewPage');
#
#
# 	tracker.enableLinkTracking();
# 	// handlers and their subscription for cart events
#
#
# 	function trackAddToCart_piwik(productCode, quantityAdded, cartData) {
# 		tracker.setEcommerceView(String(cartData.productCode),  // (required) SKU: Product unique identifier
# 				cartData.productName,  // (optional) Product name
# 				[ ], // (optional) Product category, string or array of up to 5 categories
# 				quantityAdded+""  // (optional, default to 1) Product quantity
# 		);
# 		tracker.addEcommerceItem(String(cartData.productCode),  // (required) SKU: Product unique identifier
# 				cartData.productName,  // (optional) Product name
# 				[ ], // (optional) Product category, string or array of up to 5 categories
# 				cartData.productPrice+"", // (recommended) Product price
# 				quantityAdded+""  // (optional, default to 1) Product quantity
# 		);
#
# 		if (!cartData.cartCode)
# 		{
# 			cartData.cartCode="";
# 		}
# 		tracker.setCustomVariable(1,"ec_id",cartData.cartCode,"page");
# 		tracker.trackEcommerceCartUpdate(
# 				'0'  // (required) Cart amount
# 		);
# 	}
#
# 	function trackBannerClick_piwik(url) {
# 		tracker.setCustomVariable(1,"bannerid",url,"page");
# 		tracker.trackLink(url, 'banner');
# 	}
#
# 	function trackContinueCheckoutClick_piwik() {
# 		tracker.setCustomVariable(1,"ec_id","","page");
# 		tracker.trackEvent('checkout', 'proceed', '','');
# 	}
#
#     function trackShowReview_piwik() {
#         tracker.trackEvent('review', 'view', '', '');
#     }
#
# 	function trackUpdateCart_piwik(productCode,initialQuantity,newQuantity,cartData) {
# 		if (initialQuantity != newQuantity) {
# 			trackAddToCart_piwik(productCode, newQuantity,cartData);
# 		}
# 	}
#
# 	function trackRemoveFromCart_piwik(productCode, initialQuantity,cartData) {
# 		trackAddToCart_piwik(productCode, 0, cartData);
# 	}
#
# 	window.mediator.subscribe('trackAddToCart', function(data) {
# 		if (data.productCode && data.quantity) {
# 			trackAddToCart_piwik(data.productCode, data.quantity,data.cartData);
# 		}
# 	});
#
# 	window.mediator.subscribe('trackUpdateCart', function(data) {
# 		if (data.productCode && data.initialCartQuantity && data.newCartQuantity) {
# 			trackUpdateCart_piwik(data.productCode,data.initialCartQuantity,data.newCartQuantity,data);
# 		}
# 	});
#
# 	window.mediator.subscribe('trackRemoveFromCart', function(data) {
# 		if (data.productCode && data.initialCartQuantity) {
# 			trackRemoveFromCart_piwik(data.productCode, data.initialCartQuantity,data);
# 		}
# 	});
#
#     window.mediator.subscribe('trackShowReviewClick', function() {
#         trackShowReview_piwik();
#     });
#
# 	$('.simple-banner').click(function(){
#  		trackBannerClick_piwik( $(this).find("a").prop('href'));
# 	});
#
# 	$('.js-continue-checkout-button').click(function(){
# 		trackContinueCheckoutClick_piwik();
# 	});
#
# </script> <noscript><p><img alt="" src="?idsite=1" style="border:0;"/></p></noscript> <script type="text/javascript">
# 	var analyticsConfig;
# 	if(typeof ACC != 'undefined'){
# 		analyticsConfig = ACC.addons.hybrisanalyticsaddon;
# 	}else{
# 		analyticsConfig = ACCMOB.addons.hybrisanalyticsaddon;
# 	}
# 	var piwikTrackerUrl = "https:\/\/www.checkers.co.za\/events"; // Use Piwik HTTPS Endpoint by default
# 	var piwikSiteId = "1";
# 	var sessionId = "7b3262f7-404c-4995-910f-4698bc5b8c4d";
#
# 	if(location.protocol != 'https:')	// if the current page does not use https protocol, use the normal HTTP endpoint:
# 	{
# 		piwikTrackerUrl = "http:\/\/www.checkers.co.za\/events";
# 	}
#
# 	var tracker = Piwik.getAsyncTracker(piwikTrackerUrl, piwikSiteId);
#
# 	tracker.setTrackerUrl(piwikTrackerUrl);
# 	tracker.setSiteId(piwikSiteId);
# 	tracker.setRequestMethod('POST');
# 	tracker.setRequestContentType('application/json; charset=UTF-8');
#
# 	var processPiwikRequest = (function (request) {
# 		try {
# 			var pairs = request.split('&');
#
# 			var requestParametersArray = {};
# 			for (index = 0; index < pairs.length; ++index) {
# 				var pair = pairs[index].split('=');
# 				requestParametersArray[pair[0]] = decodeURIComponent(pair[1] || '');
# 			}
# 			requestParametersArray['sessionId'] = sessionId;
#
# 			return JSON.stringify(requestParametersArray);
# 		} catch (err) {
# 			return request;
# 		}
# 	});
#
# 	tracker.setCustomRequestProcessing(processPiwikRequest);
#
# 	var hybrisAnalyticsPiwikPlugin = (function() {
# 		function _getEventtypeParam(suffix) { return '&eventtype=' + suffix; }
# 		function ecommerce() { return _getEventtypeParam("ecommerce"); }
# 		function event() { return _getEventtypeParam("event"); }
# 		function goal() { return _getEventtypeParam("goal"); }
# 		function link() { return _getEventtypeParam("link"); }
# 		function load() { return _getEventtypeParam("load"); }
# 		function log() { return _getEventtypeParam("log"); }
# 		function ping() { return _getEventtypeParam("ping"); }
# 		function run() { return _getEventtypeParam("run"); }
# 		function sitesearch() { return _getEventtypeParam("sitesearch"); }
# 		function unload() { return _getEventtypeParam("unload"); }
#
# 		return {
# 			ecommerce: ecommerce,
# 			event : event,
# 			goal : goal,
# 			link : link,
# 			load : load,
# 			log : log,
# 			ping: ping,
# 			sitesearch : sitesearch,
# 			unload : unload
# 		};
# 	})();
# 	tracker.addPlugin('hybrisAnalyticsPiwikPlugin', hybrisAnalyticsPiwikPlugin);
# 	// Hybris Analytics specifics - END
#
#
#
# 			//Otherwise default to page view event
# 			tracker.trackPageView('ViewPage');
#
#
# 	tracker.enableLinkTracking();
# 	// handlers and their subscription for cart events
#
#
# 	function trackAddToCart_piwik(productCode, quantityAdded, cartData) {
# 		tracker.setEcommerceView(String(cartData.productCode),  // (required) SKU: Product unique identifier
# 				cartData.productName,  // (optional) Product name
# 				[ ], // (optional) Product category, string or array of up to 5 categories
# 				quantityAdded+""  // (optional, default to 1) Product quantity
# 		);
# 		tracker.addEcommerceItem(String(cartData.productCode),  // (required) SKU: Product unique identifier
# 				cartData.productName,  // (optional) Product name
# 				[ ], // (optional) Product category, string or array of up to 5 categories
# 				cartData.productPrice+"", // (recommended) Product price
# 				quantityAdded+""  // (optional, default to 1) Product quantity
# 		);
#
# 		if (!cartData.cartCode)
# 		{
# 			cartData.cartCode="";
# 		}
# 		tracker.setCustomVariable(1,"ec_id",cartData.cartCode,"page");
# 		tracker.trackEcommerceCartUpdate(
# 				'0'  // (required) Cart amount
# 		);
# 	}
#
# 	function trackBannerClick_piwik(url) {
# 		tracker.setCustomVariable(1,"bannerid",url,"page");
# 		tracker.trackLink(url, 'banner');
# 	}
#
# 	function trackContinueCheckoutClick_piwik() {
# 		tracker.setCustomVariable(1,"ec_id","","page");
# 		tracker.trackEvent('checkout', 'proceed', '','');
# 	}
#
#     function trackShowReview_piwik() {
#         tracker.trackEvent('review', 'view', '', '');
#     }
#
# 	function trackUpdateCart_piwik(productCode,initialQuantity,newQuantity,cartData) {
# 		if (initialQuantity != newQuantity) {
# 			trackAddToCart_piwik(productCode, newQuantity,cartData);
# 		}
# 	}
#
# 	function trackRemoveFromCart_piwik(productCode, initialQuantity,cartData) {
# 		trackAddToCart_piwik(productCode, 0, cartData);
# 	}
#
# 	window.mediator.subscribe('trackAddToCart', function(data) {
# 		if (data.productCode && data.quantity) {
# 			trackAddToCart_piwik(data.productCode, data.quantity,data.cartData);
# 		}
# 	});
#
# 	window.mediator.subscribe('trackUpdateCart', function(data) {
# 		if (data.productCode && data.initialCartQuantity && data.newCartQuantity) {
# 			trackUpdateCart_piwik(data.productCode,data.initialCartQuantity,data.newCartQuantity,data);
# 		}
# 	});
#
# 	window.mediator.subscribe('trackRemoveFromCart', function(data) {
# 		if (data.productCode && data.initialCartQuantity) {
# 			trackRemoveFromCart_piwik(data.productCode, data.initialCartQuantity,data);
# 		}
# 	});
#
#     window.mediator.subscribe('trackShowReviewClick', function() {
#         trackShowReview_piwik();
#     });
#
# 	$('.simple-banner').click(function(){
#  		trackBannerClick_piwik( $(this).find("a").prop('href'));
# 	});
#
# 	$('.js-continue-checkout-button').click(function(){
# 		trackContinueCheckoutClick_piwik();
# 	});
#
# </script> <noscript><p><img alt="" src="?idsite=1" style="border:0;"/></p></noscript> </body> <script data-template="store-results-tmp" type="text/template">
#     <div class="nav-store-your-results">
#         <div class="nav-store-your-row">
#             <div class="nav-store-your-row__info">
#                 <a class="title js-view-store-details-btn" store-name="{{name}}"> {{displayName}} </a>
#                 <p class="description">{{line1}}</p>
#             </div>
#             <div class="nav-store-your-row__distance">
#                 <div class="store-distance {{hideDistance}}">
#                     <svg baseProfile="tiny" width="16" height="16" id="Layer_1" version="1.2" viewBox="0 0 24 24" xml:space="preserve"
#      xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                     <g>
#                         <path d="M10.368,19.102c0.349,1.049,1.011,1.086,1.478,0.086l5.309-11.375c0.467-1.002,0.034-1.434-0.967-0.967L4.812,12.154   c-1.001,0.467-0.963,1.129,0.085,1.479L9,15L10.368,19.102z">
#                         </path>
#                     </g>
# </svg><span>{{formattedDistance}}</span>
#                 </div>
#             </div>
#         </div>
#         <div class="nav-store-your-hours-simple">
#             {{opens}}
#         </div>
#         <div class="nav-store-your-store-filters">
#             {{filterOptions}}
#         </div>
#         <div class="nav-store-your-options">
#             <div class="sl-container">
#                 <button class="js-set-preferred-store-btn active"
#                         store-name="{{name}}" store-display-name="{{displayName}}">
#                     <i class="icon shoprite-icon-store-select"></i>
#                     Select Store</button>
#                 <button class="js-view-store-details-btn" type="button" store-name="{{name}}">
#                     Details</button>
#             </div>
#         </div>
#     </div>
# </script> <script class="hidden store-results-register-tmp" data-template="store-results-register-tmp" type="text/template">
#     <div class="nav-store-your-results">
#         <div class="nav-store-your-row">
#             <div class="nav-store-your-row__info">
#                 <p class="title"> {{displayName}} </p>
#                 <p class="description">{{line1}}</p>
#             </div>
#             <div class="nav-store-your-row__distance">
#                 <div class="store-distance {{hideDistance}}">
#                     <svg baseProfile="tiny" width="16" height="16" id="Layer_1" version="1.2" viewBox="0 0 24 24" xml:space="preserve"
#      xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                     <g>
#                         <path d="M10.368,19.102c0.349,1.049,1.011,1.086,1.478,0.086l5.309-11.375c0.467-1.002,0.034-1.434-0.967-0.967L4.812,12.154   c-1.001,0.467-0.963,1.129,0.085,1.479L9,15L10.368,19.102z">
#                         </path>
#                     </g>
# </svg><span>{{formattedDistance}}</span>
#                 </div>
#             </div>
#         </div>
#         <div class="nav-store-your-hours-simple">
#             {{opens}}
#         </div>
#         <div class="nav-store-your-store-filters">
#             {{filterOptions}}
#         </div>
#         <div class="nav-store-your-options">
#             <div class="sl-container">
#                 <button class="js-set-preferred-store-btn active"  type="button"
#                         store-display-name="{{displayName}}" store-name="{{name}}">
#                     <i class="icon shoprite-icon-store-select"></i>
#                     Select Store</button>
#             </div>
#         </div>
#     </div>
# </script> <script class="hidden" data-template="faq-response-header-tmp" type="text/template">
#     <h4>SUGGESTED KEYWORDS</h4>
#     <hr/>
# </script> <script class="hidden" data-template="faq-response-body-tmp" type="text/template">
#     <div class="popular-questions">
#         <a href="{{url}}">{{question}}</a>
#     </div>
# </script> <script data-template="preferred-store-closed-modal-tmp" type="text/template"> </script> </html>

# %%
product_links = extract_product_links(search_result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [237], in <cell line: 1>()
# ----> 1 product_links = extract_product_links(search_result)
#
# Input In [208], in extract_product_links(html_page)
#       1 def extract_product_links(html_page):
#       3     product_div = html_page.find('div', {"class": re.compile('(\w+-)*search-landing')})
# ----> 4     content = product_div.find('div', class_='yCmsContentSlot')
#       5     component = content.find('div', class_='yCmsComponent')
#       6     product_wrappers = component.find('div', class_='search-landing__block--products')
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
product_links
# Out:
# ['/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Checkers-Housebrand-Kitchen-Roller-Towels-2-Pack/p/10159233EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Twinsaver-White-Roller-Towels-2-Pack/p/10143493EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Twinsaver-White-Roller-Towels-4-Pack/p/10141762EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Dinu-Mega-Kitchen-Towels-2-Pack/p/10484372EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Dinu-White-Kitchen-Towels-2-Pack/p/10336810EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Checkers-Housebrand-Kitchen-Towels-4-Pack/p/10752869EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Essentials-Terry-Kitchen-Towels-%28Assorted-Product---Single-Item%29-2-Pack/p/10497247EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Kitchen-Towels/Essentials-Assorted-Flat-Weave-Kitchen-Towels-40-x-70cm-2-Pack/p/10742031EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Essentials-Premium-Terry-Kitchen-Cloths-Assorted-2-Pack/p/10540717EA',
#  '/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Essentials-Woven-Kitchen-Swab-Towels-3-Pack/p/10703454EA']

# %%
product_match = match_product_url(product_links, 'kitchen roller towels 2 pack')

# %%
product_match
# Out:
# [{'/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Checkers-Housebrand-Kitchen-Roller-Towels-2-Pack/p/10159233EA': '/all-departments/household/cleaning/kitchen-towels%2c-cloths-and-dusters/checkers-housebrand-kitchen-roller-towels-2-pack/p/10159233ea'}]

# %%
import pandas as pd
# Out:
# <style type="text/css">
# </style>
# <table id="T_bfcb8" style='display:inline; margin:30px; text-align:center'>
#   <caption>Caption table 1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfcb8_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfcb8_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_bfcb8_row0_col0" class="data row0 col0" >Apple</td>
#     </tr>
#     <tr>
#       <th id="T_bfcb8_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_bfcb8_row1_col0" class="data row1 col0" >Banana</td>
#     </tr>
#     <tr>
#       <th id="T_bfcb8_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_bfcb8_row2_col0" class="data row2 col0" >Candle</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9e31a" style='display:inline; margin:30px; text-align:center'>
#   <caption>Caption table 2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e31a_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e31a_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_9e31a_row0_col0" class="data row0 col0" >Apple</td>
#     </tr>
#     <tr>
#       <th id="T_9e31a_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_9e31a_row1_col0" class="data row1 col0" >Banana</td>
#     </tr>
#     <tr>
#       <th id="T_9e31a_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_9e31a_row2_col0" class="data row2 col0" >Candle</td>
#     </tr>
#   </tbody>
# </table>

# %%
product_brands = get_brands(product_match)

# %%
product_brands
# Out:
# [{1: 'Checkers Housebrand Kitchen Roller Towels 2 Pack'}]

# %%
user_choice = input('select brand > ')
# Out:
# select brand >  1

# %%
html = evaluate_user_choice(user_choice, product_links, product_match, product_brands, 'no sugar soft drink bottle 500ml', CHECKERS_URL)
product_details = get_product_details(html)
# Out:
# html downloaded successfully

# %%
html.head
# Out:
# <head> <title> Checkers Housebrand Kitchen Roller Towels 2 Pack | Kitchen Towels, Cloths &amp; Dusters | Cleaning | Household | Checkers ZA</title> <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/> <meta name="keywords"/> <meta name="description"/> <meta content="https://www.checkers.co.za/All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Checkers-Housebrand-Kitchen-Roller-Towels-2-Pack/p/10159233EA" property="og:url"/> <meta content="Checkers Housebrand Kitchen Roller Towels 2 Pack" property="og:title"/> <meta property="og:description"/> <meta content="https://www.checkers.co.za/medias/10159233EA-20190726-Media-checkers300Wx300H?context=bWFzdGVyfGltYWdlc3w1MTE0MXxpbWFnZS9wbmd8aW1hZ2VzL2hjYS9oODkvODg1ODAyNjExNTEwMi5wbmd8N2I0NjkzNjllN2VjMmViNmExMDIyMDM3NTc0MTk1YTE1NDhmZDQ0ZWQ5YTk3NWMzMzdlMDdmZGUwM2IwOTg1MQ" property="og:image"/> <meta content="https://www.checkers.co.za/medias/10159233EA-20190726-Media-checkers300Wx300H?context=bWFzdGVyfGltYWdlc3w1MTE0MXxpbWFnZS9wbmd8aW1hZ2VzL2hjYS9oODkvODg1ODAyNjExNTEwMi5wbmd8N2I0NjkzNjllN2VjMmViNmExMDIyMDM3NTc0MTk1YTE1NDhmZDQ0ZWQ5YTk3NWMzMzdlMDdmZGUwM2IwOTg1MQ" property="og:image:secure_url"/> <meta content="summary" property="twitter:card"/> <meta content="Checkers Housebrand Kitchen Roller Towels 2 Pack" property="twitter:title"/> <meta property="twitter:description"/> <meta content="https://www.checkers.co.za/medias/10159233EA-20190726-Media-checkers300Wx300H?context=bWFzdGVyfGltYWdlc3w1MTE0MXxpbWFnZS9wbmd8aW1hZ2VzL2hjYS9oODkvODg1ODAyNjExNTEwMi5wbmd8N2I0NjkzNjllN2VjMmViNmExMDIyMDM3NTc0MTk1YTE1NDhmZDQ0ZWQ5YTk3NWMzMzdlMDdmZGUwM2IwOTg1MQ" property="twitter:image"/> <meta content="index,follow" name="robots"/> <meta content="H16-wEJW_mSEwjpLumaZS5S_X0ZA3XjXWHiHaXGX_Ks" name="google-site-verification"> <meta content="a463fb8adf6a8f705e9fd4184ec03f2873cf1e99f68e38fb81b352aec15191c4" name="ahrefs-site-verification"> <meta content="1f5e98eddf473cf817f59bb620e71ad1" name="p:domain_verify"> <link href="/_ui/responsive/theme-checkers/images/favicon.ico" media="all" rel="shortcut icon" type="image/x-icon"/> <link href="https://www.checkers.co.za//All-Departments/Household/Cleaning/Kitchen-Towels%2C-Cloths-and-Dusters/Checkers-Housebrand-Kitchen-Roller-Towels-2-Pack/p/10159233EA" rel="canonical"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/glyphicons-halflings-regular.woff" rel="preload" type="font/woff"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/glyphicons-halflings-regular.woff2" rel="preload" type="font/woff2"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/shoprite-icon.ttf?xo7m3y" rel="preload" type="font/ttf"/> <link as="font" crossorigin="anonymous" href="/_ui/responsive/theme-checkers/fonts/bebasneue_bold-webfont.otf" rel="preload" type="font/otf"/> <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic,800,800italic" rel="stylesheet" type="text/css"> <link href="/_ui/responsive/theme-checkers/css/style.css" media="all" rel="stylesheet" type="text/css"> <link href="/_ui/addons/assistedservicestorefront/responsive/common/css/assistedservicestorefront.css" media="all" rel="stylesheet" type="text/css"> <link href="/_ui/addons/assistedservicestorefront/responsive/common/css/storeFinder.css" media="all" rel="stylesheet" type="text/css"> <link href="/_ui/addons/assistedservicestorefront/responsive/common/css/customer360.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/hybrisanalyticsaddon/responsive/common/css/hybrisanalyticsaddon.css" media="all" rel="stylesheet" type="text/css"/> <link href="/_ui/addons/shopriteassistedservicestorefront/responsive/common/css/shopriteassistedservicestorefront.css ...
# 		/*<![CDATA[*/
#
# 		var ACC = { config: {}, user: {} };
# 			ACC.config.contextPath = '';
# 			ACC.config.encodedContextPath = '';
# 			ACC.config.commonResourcePath = '\/_ui\/responsive\/common';
# 			ACC.config.themeResourcePath = '\/_ui\/responsive\/theme-checkers';
# 			ACC.config.siteResourcePath = '\/_ui\/responsive\/site-checkersZA';
# 			ACC.config.rootPath = '\/_ui\/responsive';
# 			ACC.config.CSRFToken = '5a95a9f1-e078-49e6-a637-dd52adac48a0';
# 			ACC.config.recaptchaKey='';
# 			ACC.pwdStrengthVeryWeak = 'Very weak';
# 			ACC.pwdStrengthWeak = 'Weak';
# 			ACC.pwdStrengthMedium = 'Medium';
# 			ACC.pwdStrengthStrong = 'Strong';
# 			ACC.pwdStrengthVeryStrong = 'Very strong';
# 			ACC.pwdStrengthUnsafePwd = 'password.strength.unsafepwd';
# 			ACC.pwdStrengthTooShortPwd = 'Too short';
# 			ACC.pwdStrengthMinCharText = 'Minimum length is %d characters';
# 			ACC.accessibilityLoading = 'Loading... Please wait...';
# 			ACC.accessibilityStoresLoaded = 'Stores loaded';
# 			ACC.config.googleApiKey='AIzaSyDqAJj-wXYWuALzQnCjYoMc3tit8SaGYWc';
# 			ACC.config.googleApiVersion='3.7';
# 			ACC.config.googleMapIconPath='\/_ui\/responsive\/common\/images\/icons\/CheckersMapPin.svg';
# 			ACC.config.googleMapZoomInIconPath='\/_ui\/responsive\/common\/images\/icons\/ZoomIn.svg';
# 			ACC.config.googleMapZoomOutIconPath='\/_ui\/responsive\/common\/images\/icons\/ZoomOut.svg';
# 			ACC.config.googleLoadDirections='';
# 			ACC.config.asmLoggedIn='false';
# 			ACC.config.verifyEmail='';
# 			ACC.config.currentCurrencyIsoCode = 'ZAR';
# 			ACC.user.customerId='00000000';
# 			ACC.user.loggedIn=false;
#
#
# 			ACC.autocompleteUrl = '\/search\/autocompleteSecure';
#
#
# 			ACC.config.loginUrl = '\/login';
#
#
# 			ACC.config.authenticationStatusUrl = '\/authentication\/status';
#
#
# 		/*]]>*/
# 	</script> <script>
# 	/*<![CDATA[*/
# 	ACC.addons = {};	//JS namespace for addons properties
#
#
# 		ACC.addons['shopriteymktaddon'] = [];
#
# 		ACC.addons['shopriteassistedservicestorefront'] = [];
#
# 		ACC.addons['smarteditaddon'] = [];
#
# 		ACC.addons['shopritemediacompression'] = [];
#
# 		ACC.addons['assistedservicestorefront'] = [];
#
# 				ACC.addons['assistedservicestorefront']['asm.timer.min'] = 'min';
#
# 		ACC.addons['eventtrackingwsaddon'] = [];
#
# 		ACC.addons['hybrisanalyticsaddon'] = [];
#
# 	/*]]>*/
# </script> <script defer="" src="/_ui/shared/js/generatedVariables.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery-3.6.0.min.js"></script> <script defer="" src="/_ui/responsive/common/js/enquire.min.js"></script> <script defer="" src="/_ui/responsive/common/js/Imager.min.js"></script> <script defer="" src="/_ui/responsive/common/js/purify.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.blockUI-2.66.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.colorbox-min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.form.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.hoverIntent.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.pstrength.custom-1.2.0.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.syncheight.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.tabs.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery-ui-1.12.1.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.zoom.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/owl.carousel.custom.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.tmpl-1.0.0pre.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.currencies.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.waitforimages.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.slideviewer.custom.1.2.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.validate.js"></script> <script defer="" src="/_ui/responsive/common/js/js.cookie.min.js"></script> <script defer="" src="/_ui/responsive/common/js/sharer.js"></script> <script defer="" src="/_ui/responsive/common/js/drift.js"></script> <script defer="" src="/_ui/responsive/common/js/pinch-zoom.js"></script> <script defer="" src="/_ui/responsive/common/bootstrap/js/bootstrap.js"></script> <script defer="" src="/_ui/responsive/common/js/cleave.js"></script> <script defer="" src="/_ui/responsive/common/js/moment.min.js"></script> <script defer="" src="/_ui/responsive/common/js/bootstrap-datetimepicker.min.js"></script> <script defer="" src="/_ui/responsive/common/js/handlebars.min.js"></script> <script defer="" src="/_ui/responsive/common/js/typeahead.bundle.js"></script> <script defer="" src="/_ui/responsive/common/js/datatables.min.js"></script> <script defer="" src="/_ui/responsive/common/js/jquery.daterangepicker.js"></script> <script defer="" src="/_ui/responsive/common/js/tiny-slider.js"></script> <script defer="" src="/_ui/responsive/common/js/swiper.js"></script> <script defer="" src="/_ui/responsive/common/js/html2canvas.js"></script> <script defer="" src="/_ui/responsive/common/js/jspdf.umd.min.js"></script> <script defer="" src="/_ui/responsive/common/js/localization/messages.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.track.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.shopriteutils.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.localization.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.common.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.address.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.autocomplete.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.carousel.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.ajaxcarousel.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.masthead.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.savingsandslips.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.ajaxcomponent.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.cart.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.cartitem.js"></script> <script defer="" src="/_ui/responsive/common/js/acc.checkout.js"></script> <sc ...
#     w[l] = w[l] || [];
#     w[l].push({
#         'gtm.start':
#
#             new Date().getTime(), event: 'gtm.js'
#     });
#     var f = d.getElementsByTagName(s)[0],
#
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
#
# })(window, document, 'script', 'dataLayer', 'GTM-597TTQ');</script> <script defer="" type="application/ld+json">
#         {
#            "@context": "https://schema.org/",
#            "@type": "Product",
#            "prod_code": "10159233EA",
#            "brand": "Checkers Housebrand",
#            "price": "R21.99",
#            "cat": "Kitchen Towels, Cloths & Dusters",
#            "mat_type": "OTHER"
#         }
#     </script> <script defer="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script> <script defer="" type="text/javascript">
#         window.googletag = window.googletag || {cmd: []};
#         googletag.cmd.push(function () {
#             const mapping1 = googletag.sizeMapping()
#                 .addSize([1280, 0], [[970, 90]])
#                 .addSize([760, 0], [[728, 90]])
#                 .addSize([0, 0], [[320, 100], [320, 50]])
#                 .build();
#
#             googletag.defineSlot("/22346593009/checkers-web/household/cleaning/kitchen_towels_cloths_and_dusters/checkers_housebrand_kitchen_roller_towels_2_pack", [[970, 90], [728, 90], [320, 100], [320, 50]], "gpt-ad-1")
#                 .setTargeting("pos", ["1"])
#                 .defineSizeMapping(mapping1)
#                 .addService(googletag.pubads());
#
#             googletag.pubads().setTargeting("prod_code", "10159233EA");
#             googletag.pubads().setTargeting("tag", "");
#             googletag.pubads().setTargeting("search", "");
#             googletag.pubads().setTargeting("serve_size", "");
#             googletag.pubads().setTargeting("recipe_type", "");
#             googletag.pubads().setTargeting("price", "R21.99");
#             googletag.pubads().setTargeting("prep_time", "");
#             googletag.pubads().setTargeting("no_ingredients", "");
#             googletag.pubads().setTargeting("mat_type", "OTHER");
#             googletag.pubads().setTargeting("ingredients", "");
#             googletag.pubads().setTargeting("diet", "");
#             googletag.pubads().setTargeting("dc_seg", "");
#             googletag.pubads().setTargeting("cat", "Kitchen Towels, Cloths & Dusters");
#             googletag.pubads().setTargeting("brand", "Checkers Housebrand");
#             googletag.pubads().setTargeting("art_guar", "");
#             googletag.pubads().setTargeting("allegens", "");
#             googletag.pubads().setTargeting("user_type", "anonymous");
#             googletag.pubads().collapseEmptyDivs();
#             googletag.pubads().setCentering(true);
#             googletag.pubads().enableLazyLoad();
#             googletag.enableServices();
#         });
#     </script> <script defer="">
#     window.lazySizesConfig = window.lazySizesConfig || {};
#     window.lazySizesConfig.srcAttr = 'data-original-src';
#     window.lazySizesConfig.srcsetAttr = 'data-original-srcset';
# </script> <script defer="" src="/_ui/responsive/common/js/lazysizes.min.js"></script> <script defer="" src="/_ui/responsive/common/js/rbm.checkersZA.js"></script> <script defer="" src="/_ui/responsive/common/js/_autoload.js"></script> </link></link></link></link></meta></meta></meta></head>

# %%
offer = product_details.find('div', class_= 'extra-message--xtra-savings')
# promo_price_1 = re.search(regex, offer).group()

# %%
offer

# %%
x = None
y= None

print(not x and not y)
# Out:
# True
